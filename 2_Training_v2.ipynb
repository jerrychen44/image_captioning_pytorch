# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**</p>
#
# Image caption uses an encoder-decoder architecture, I use Rest-50 as a feature extractor encoder, and use
# LSTM as the decoder to achieve end-to-end image captioning.
#
# batch_size = 128
# =>Can speed up the training process under the GPU capability.
#
# embed_size = 512
# hidden_size= 512
# =>From paper Show and Tell: A Neural Image Caption Generator, sec 4.2.3 "We used 512 dimensions for the embeddings and the size of the LSTM memory"
#
# vocab_threshold = 5
# =>No particular tuning, for me it makes sense if the word appears more than five times then count it.
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** </p>
#
# I think the default transform process is reasonable, becasue the input size of encoder is 224x224.
# Thus, we resize all img to 256 first, and random crop to 224x224.
# The RandomHorizontalFlip() and ColorJitter() are helping to increase the input data number.
# I think, maybe the random brightness , contrast change will help the model more robust.
#
#     transforms.Resize(256)                          # smaller edge of image resized to 256
#     transforms.RandomCrop(224)                      # get 224x224 crop from random location
#     transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0),# marked first
#     transforms.RandomHorizontalFlip()               # horizontally flip image with probability=0.5
#     transforms.ToTensor()                           # convert the PIL Image to a tensor
#     transforms.Normalize((0.485, 0.456, 0.406),     # normalize image for pre-trained model
#                          (0.229, 0.224, 0.225))]
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** </p>
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
#
# parameter in decoder and encoder are must have.</p>
#
# For the decoder, that is because the final layer be transfored as a feature vector.</p>
#
# For the encoder, that is what we need to train from scratch.</p>
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** </p>
# In paper "Show, Attend and Tell: Neural Image Caption Generation with Visual Attention ": we used the recently proposed Adam algorithm.

# %%
#quick test before real train

import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('../cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math
import os

## TODO #1: Select appropriate values for the Python variables below.
batch_size = 128          # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 128#512        # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 5             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'models/training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0),
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# %%
# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file,
                         cocoapi_loc="../")

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
#   0%|          | 0/414113 [00:00<?, ?it/s]
# Done (t=0.49s)
# creating index...
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [00:32<00:00, 12916.47it/s]

# %%
# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size, num_LSTM_layers=1)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters()) 

# TODO #4: Define the optimizer.
learning_rate = 0.001
optimizer = torch.optim.Adam(params, lr=learning_rate, betas=(0.9, 0.999), eps=1e-08)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)

#save testing
testepoch = 1
torch.save(decoder.state_dict(), os.path.join('./models',
                                             'decoder_'+str(testepoch)+'_'+
                                              str(batch_size)+'_'+
                                              str(learning_rate)+'_'+
                                              str(num_epochs)+'_'+
                                              str(total_step)+'_'+
                                              str(embed_size)+'_'+
                                              str(hidden_size)+'_'+
                                              str(vocab_threshold)+'.pkl'))

torch.save(encoder.state_dict(), os.path.join('./models', 
                                                'encoder_'+str(testepoch)+'_'+
                                                  str(batch_size)+'_'+
                                                  str(learning_rate)+'_'+
                                                  str(num_epochs)+'_'+
                                                  str(total_step)+'_'+
                                                  str(embed_size)+'_'+
                                                  str(hidden_size)+'_'+
                                                  str(vocab_threshold)+'.pkl'))
# Out:
# self.embed_size 128
# self.hidden_size 512
# self.vocab_size 8855
# self.num_LSTM_layers 1
# self.device cuda

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
#import os
import requests
import time


print(total_step)
print(num_epochs)

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
#marked in loacl 
#response = requests.request("GET", 
#                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
#                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            #marked in loacl 
            #requests.request("POST", 
            #                 "https://nebula.udacity.com/api/v1/remote/keep-alive", 
            #                 headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r'+time.strftime("%H:%M:%S"))
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models',
                                                     'decoder_'+str(epoch)+'_'+
                                                      str(batch_size)+'_'+
                                                      str(learning_rate)+'_'+
                                                      str(num_epochs)+'_'+
                                                      str(total_step)+'_'+
                                                      str(embed_size)+'_'+
                                                      str(hidden_size)+'_'+
                                                      str(vocab_threshold)+'.pkl'))

        torch.save(encoder.state_dict(), os.path.join('./models', 
                                                        'encoder_'+str(epoch)+'_'+
                                                          str(batch_size)+'_'+
                                                          str(learning_rate)+'_'+
                                                          str(num_epochs)+'_'+
                                                          str(total_step)+'_'+
                                                          str(embed_size)+'_'+
                                                          str(hidden_size)+'_'+
                                                          str(vocab_threshold)+'.pkl'))

# Close the training log file.
f.close()
# Out:
# 3236
# 5
# Epoch [1/5], Step [100/3236], Loss: 3.8352, Perplexity: 46.304314:22:46
# Epoch [1/5], Step [100/3236], Loss: 3.8352, Perplexity: 46.3043
# Epoch [1/5], Step [200/3236], Loss: 3.4837, Perplexity: 32.5789814:27:54
# Epoch [1/5], Step [200/3236], Loss: 3.4837, Perplexity: 32.5789
# Epoch [1/5], Step [300/3236], Loss: 3.2783, Perplexity: 26.531514:32:50
# Epoch [1/5], Step [300/3236], Loss: 3.2783, Perplexity: 26.5315
# Epoch [1/5], Step [400/3236], Loss: 3.7620, Perplexity: 43.033814:37:56
# Epoch [1/5], Step [400/3236], Loss: 3.7620, Perplexity: 43.0338
# Epoch [1/5], Step [500/3236], Loss: 3.8307, Perplexity: 46.096314:42:57
# Epoch [1/5], Step [500/3236], Loss: 3.8307, Perplexity: 46.0963
# Epoch [1/5], Step [600/3236], Loss: 3.2225, Perplexity: 25.090614:47:53
# Epoch [1/5], Step [600/3236], Loss: 3.2225, Perplexity: 25.0906
# Epoch [1/5], Step [700/3236], Loss: 3.4061, Perplexity: 30.148714:52:44
# Epoch [1/5], Step [700/3236], Loss: 3.4061, Perplexity: 30.1487
# Epoch [1/5], Step [800/3236], Loss: 2.7716, Perplexity: 15.984714:57:37
# Epoch [1/5], Step [800/3236], Loss: 2.7716, Perplexity: 15.9847
# Epoch [1/5], Step [900/3236], Loss: 3.1002, Perplexity: 22.203415:02:23
# Epoch [1/5], Step [900/3236], Loss: 3.1002, Perplexity: 22.2034
# Epoch [1/5], Step [1000/3236], Loss: 2.9800, Perplexity: 19.687015:06:56
# Epoch [1/5], Step [1000/3236], Loss: 2.9800, Perplexity: 19.6870
# Epoch [1/5], Step [1100/3236], Loss: 2.7901, Perplexity: 16.282815:11:35
# Epoch [1/5], Step [1100/3236], Loss: 2.7901, Perplexity: 16.2828
# Epoch [1/5], Step [1200/3236], Loss: 2.8768, Perplexity: 17.757015:16:33
# Epoch [1/5], Step [1200/3236], Loss: 2.8768, Perplexity: 17.7570
# Epoch [1/5], Step [1300/3236], Loss: 2.6676, Perplexity: 14.404715:21:18
# Epoch [1/5], Step [1300/3236], Loss: 2.6676, Perplexity: 14.4047
# Epoch [1/5], Step [1400/3236], Loss: 2.5975, Perplexity: 13.430615:25:54
# Epoch [1/5], Step [1400/3236], Loss: 2.5975, Perplexity: 13.4306
# Epoch [1/5], Step [1500/3236], Loss: 2.4519, Perplexity: 11.610915:30:26
# Epoch [1/5], Step [1500/3236], Loss: 2.4519, Perplexity: 11.6109
# Epoch [1/5], Step [1600/3236], Loss: 2.4727, Perplexity: 11.8546315:34:56
# Epoch [1/5], Step [1600/3236], Loss: 2.4727, Perplexity: 11.8546
# Epoch [1/5], Step [1700/3236], Loss: 2.4835, Perplexity: 11.983215:39:27
# Epoch [1/5], Step [1700/3236], Loss: 2.4835, Perplexity: 11.9832
# Epoch [1/5], Step [1800/3236], Loss: 2.7903, Perplexity: 16.286115:44:03
# Epoch [1/5], Step [1800/3236], Loss: 2.7903, Perplexity: 16.2861
# Epoch [1/5], Step [1900/3236], Loss: 2.5991, Perplexity: 13.451115:48:45
# Epoch [1/5], Step [1900/3236], Loss: 2.5991, Perplexity: 13.4511
# Epoch [1/5], Step [2000/3236], Loss: 2.3887, Perplexity: 10.899515:53:32
# Epoch [1/5], Step [2000/3236], Loss: 2.3887, Perplexity: 10.8995
# Epoch [1/5], Step [2100/3236], Loss: 2.3421, Perplexity: 10.403515:58:28
# Epoch [1/5], Step [2100/3236], Loss: 2.3421, Perplexity: 10.4035
# Epoch [1/5], Step [2200/3236], Loss: 2.7532, Perplexity: 15.692416:03:20
# Epoch [1/5], Step [2200/3236], Loss: 2.7532, Perplexity: 15.6924
# Epoch [1/5], Step [2300/3236], Loss: 2.5390, Perplexity: 12.666916:08:17
# Epoch [1/5], Step [2300/3236], Loss: 2.5390, Perplexity: 12.6669
# Epoch [1/5], Step [2400/3236], Loss: 2.2919, Perplexity: 9.8934416:13:09
# Epoch [1/5], Step [2400/3236], Loss: 2.2919, Perplexity: 9.8934
# Epoch [1/5], Step [2500/3236], Loss: 2.2533, Perplexity: 9.5192516:17:59
# Epoch [1/5], Step [2500/3236], Loss: 2.2533, Perplexity: 9.5192
# Epoch [1/5], Step [2600/3236], Loss: 2.2043, Perplexity: 9.0640116:22:58
# Epoch [1/5], Step [2600/3236], Loss: 2.2043, Perplexity: 9.0640
# Epoch [1/5], Step [2700/3236], Loss: 2.4951, Perplexity: 12.122816:27:57
# Epoch [1/5], Step [2700/3236], Loss: 2.4951, Perplexity: 12.1228
# Epoch [1/5], Step [2800/3236], Loss: 2.3337, Perplexity: 10.315716:33:11
# Epoch [1/5], Step [2800/3236], Loss: 2.3337, Perplexity: 10.3157
# Epoch [1/5], Step [2900/3236], Loss: 2.3087, Perplexity: 10.061316:38:09
# Epoch [1/5], Step [2900/3236], Loss: 2.3087, Perplexity: 10.0613
# Epoch [1/5], Step [3000/3236], Loss: 2.3117, Perplexity: 10.091316:43:23
# Epoch [1/5], Step [3000/3236], Loss: 2.3117, Perplexity: 10.0913
# Epoch [1/5], Step [3100/3236], Loss: 2.7037, Perplexity: 14.935616:48:33
# Epoch [1/5], Step [3100/3236], Loss: 2.7037, Perplexity: 14.9356
# Epoch [1/5], Step [3200/3236], Loss: 2.1117, Perplexity: 8.2625316:53:42
# Epoch [1/5], Step [3200/3236], Loss: 2.1117, Perplexity: 8.2625
# Epoch [2/5], Step [100/3236], Loss: 2.3272, Perplexity: 10.2497517:00:43
# Epoch [2/5], Step [100/3236], Loss: 2.3272, Perplexity: 10.2497
# Epoch [2/5], Step [200/3236], Loss: 2.0836, Perplexity: 8.0330417:05:53
# Epoch [2/5], Step [200/3236], Loss: 2.0836, Perplexity: 8.0330
# Epoch [2/5], Step [300/3236], Loss: 2.1070, Perplexity: 8.2231917:11:04
# Epoch [2/5], Step [300/3236], Loss: 2.1070, Perplexity: 8.2231
# Epoch [2/5], Step [400/3236], Loss: 2.1603, Perplexity: 8.6735117:16:14
# Epoch [2/5], Step [400/3236], Loss: 2.1603, Perplexity: 8.6735
# Epoch [2/5], Step [500/3236], Loss: 2.2792, Perplexity: 9.7691317:21:20
# Epoch [2/5], Step [500/3236], Loss: 2.2792, Perplexity: 9.7691
# Epoch [2/5], Step [600/3236], Loss: 2.1696, Perplexity: 8.7550017:26:35
# Epoch [2/5], Step [600/3236], Loss: 2.1696, Perplexity: 8.7550
# Epoch [2/5], Step [700/3236], Loss: 2.4237, Perplexity: 11.288117:31:54
# Epoch [2/5], Step [700/3236], Loss: 2.4237, Perplexity: 11.2881
# Epoch [2/5], Step [800/3236], Loss: 2.3019, Perplexity: 9.9927617:37:16
# Epoch [2/5], Step [800/3236], Loss: 2.3019, Perplexity: 9.9927
# Epoch [2/5], Step [900/3236], Loss: 2.6166, Perplexity: 13.689517:42:35
# Epoch [2/5], Step [900/3236], Loss: 2.6166, Perplexity: 13.6895
# Epoch [2/5], Step [1000/3236], Loss: 2.0851, Perplexity: 8.045717:47:59
# Epoch [2/5], Step [1000/3236], Loss: 2.0851, Perplexity: 8.0457
# Epoch [2/5], Step [1100/3236], Loss: 2.2093, Perplexity: 9.1097317:53:39
# Epoch [2/5], Step [1100/3236], Loss: 2.2093, Perplexity: 9.1097
# Epoch [2/5], Step [1200/3236], Loss: 2.1877, Perplexity: 8.9149017:59:15
# Epoch [2/5], Step [1200/3236], Loss: 2.1877, Perplexity: 8.9149
# Epoch [2/5], Step [1300/3236], Loss: 2.3585, Perplexity: 10.574918:04:46
# Epoch [2/5], Step [1300/3236], Loss: 2.3585, Perplexity: 10.5749
# Epoch [2/5], Step [1400/3236], Loss: 2.1895, Perplexity: 8.9308218:10:02
# Epoch [2/5], Step [1400/3236], Loss: 2.1895, Perplexity: 8.9308
# Epoch [2/5], Step [1500/3236], Loss: 2.1484, Perplexity: 8.5708618:15:17
# Epoch [2/5], Step [1500/3236], Loss: 2.1484, Perplexity: 8.5708
# Epoch [2/5], Step [1600/3236], Loss: 2.7838, Perplexity: 16.179918:20:29
# Epoch [2/5], Step [1600/3236], Loss: 2.7838, Perplexity: 16.1799
# Epoch [2/5], Step [1700/3236], Loss: 2.1545, Perplexity: 8.6238818:26:06
# Epoch [2/5], Step [1700/3236], Loss: 2.1545, Perplexity: 8.6238
# Epoch [2/5], Step [1800/3236], Loss: 2.0545, Perplexity: 7.8033018:31:20
# Epoch [2/5], Step [1800/3236], Loss: 2.0545, Perplexity: 7.8033
# Epoch [2/5], Step [1900/3236], Loss: 2.0927, Perplexity: 8.1071718:36:34
# Epoch [2/5], Step [1900/3236], Loss: 2.0927, Perplexity: 8.1071
# Epoch [2/5], Step [2000/3236], Loss: 2.1468, Perplexity: 8.5576218:41:47
# Epoch [2/5], Step [2000/3236], Loss: 2.1468, Perplexity: 8.5576
# Epoch [2/5], Step [2100/3236], Loss: 2.8194, Perplexity: 16.767318:47:04
# Epoch [2/5], Step [2100/3236], Loss: 2.8194, Perplexity: 16.7673
# Epoch [2/5], Step [2200/3236], Loss: 2.8434, Perplexity: 17.174818:52:18
# Epoch [2/5], Step [2200/3236], Loss: 2.8434, Perplexity: 17.1748
# Epoch [2/5], Step [2300/3236], Loss: 2.0754, Perplexity: 7.9678218:57:16
# Epoch [2/5], Step [2300/3236], Loss: 2.0754, Perplexity: 7.9678
# Epoch [2/5], Step [2400/3236], Loss: 2.3809, Perplexity: 10.814719:02:27
# Epoch [2/5], Step [2400/3236], Loss: 2.3809, Perplexity: 10.8147
# Epoch [2/5], Step [2500/3236], Loss: 2.1131, Perplexity: 8.2740219:07:31
# Epoch [2/5], Step [2500/3236], Loss: 2.1131, Perplexity: 8.2740
# Epoch [2/5], Step [2600/3236], Loss: 2.2733, Perplexity: 9.7118519:12:44
# Epoch [2/5], Step [2600/3236], Loss: 2.2733, Perplexity: 9.7118
# Epoch [2/5], Step [2700/3236], Loss: 1.9929, Perplexity: 7.3366019:17:55
# Epoch [2/5], Step [2700/3236], Loss: 1.9929, Perplexity: 7.3366
# Epoch [2/5], Step [2800/3236], Loss: 1.9445, Perplexity: 6.9899519:23:05
# Epoch [2/5], Step [2800/3236], Loss: 1.9445, Perplexity: 6.9899
# Epoch [2/5], Step [2900/3236], Loss: 1.9890, Perplexity: 7.3083319:28:18
# Epoch [2/5], Step [2900/3236], Loss: 1.9890, Perplexity: 7.3083
# Epoch [2/5], Step [3000/3236], Loss: 2.0220, Perplexity: 7.5538119:33:34
# Epoch [2/5], Step [3000/3236], Loss: 2.0220, Perplexity: 7.5538
# Epoch [2/5], Step [3100/3236], Loss: 1.9594, Perplexity: 7.0948919:38:57
# Epoch [2/5], Step [3100/3236], Loss: 1.9594, Perplexity: 7.0948
# Epoch [2/5], Step [3200/3236], Loss: 2.1642, Perplexity: 8.7072719:44:25
# Epoch [2/5], Step [3200/3236], Loss: 2.1642, Perplexity: 8.7072
# Epoch [3/5], Step [100/3236], Loss: 1.9269, Perplexity: 6.86807319:51:43
# Epoch [3/5], Step [100/3236], Loss: 1.9269, Perplexity: 6.8680
# Epoch [3/5], Step [200/3236], Loss: 2.0046, Perplexity: 7.4229519:57:04
# Epoch [3/5], Step [200/3236], Loss: 2.0046, Perplexity: 7.4229
# Epoch [3/5], Step [300/3236], Loss: 2.1154, Perplexity: 8.29272320:02:20
# Epoch [3/5], Step [300/3236], Loss: 2.1154, Perplexity: 8.2927
# Epoch [3/5], Step [400/3236], Loss: 2.4473, Perplexity: 11.557520:07:35
# Epoch [3/5], Step [400/3236], Loss: 2.4473, Perplexity: 11.5575
# Epoch [3/5], Step [500/3236], Loss: 2.3780, Perplexity: 10.783220:12:57
# Epoch [3/5], Step [500/3236], Loss: 2.3780, Perplexity: 10.7832
# Epoch [3/5], Step [600/3236], Loss: 2.0159, Perplexity: 7.5071320:18:18
# Epoch [3/5], Step [600/3236], Loss: 2.0159, Perplexity: 7.5071
# Epoch [3/5], Step [700/3236], Loss: 2.0681, Perplexity: 7.9096520:23:37
# Epoch [3/5], Step [700/3236], Loss: 2.0681, Perplexity: 7.9096
# Epoch [3/5], Step [800/3236], Loss: 2.0226, Perplexity: 7.5577120:29:01
# Epoch [3/5], Step [800/3236], Loss: 2.0226, Perplexity: 7.5577
# Epoch [3/5], Step [900/3236], Loss: 1.9501, Perplexity: 7.0291920:34:20
# Epoch [3/5], Step [900/3236], Loss: 1.9501, Perplexity: 7.0291
# Epoch [3/5], Step [1000/3236], Loss: 1.9563, Perplexity: 7.072820:39:36
# Epoch [3/5], Step [1000/3236], Loss: 1.9563, Perplexity: 7.0728
# Epoch [3/5], Step [1100/3236], Loss: 2.1464, Perplexity: 8.5536920:45:23
# Epoch [3/5], Step [1100/3236], Loss: 2.1464, Perplexity: 8.5536
# Epoch [3/5], Step [1200/3236], Loss: 2.3078, Perplexity: 10.052720:51:14
# Epoch [3/5], Step [1200/3236], Loss: 2.3078, Perplexity: 10.0527
# Epoch [3/5], Step [1300/3236], Loss: 1.8782, Perplexity: 6.5420020:57:09
# Epoch [3/5], Step [1300/3236], Loss: 1.8782, Perplexity: 6.5420
# Epoch [3/5], Step [1400/3236], Loss: 1.9152, Perplexity: 6.7882321:02:56
# Epoch [3/5], Step [1400/3236], Loss: 1.9152, Perplexity: 6.7882
# Epoch [3/5], Step [1500/3236], Loss: 1.9460, Perplexity: 7.0005521:08:42
# Epoch [3/5], Step [1500/3236], Loss: 1.9460, Perplexity: 7.0005
# Epoch [3/5], Step [1600/3236], Loss: 1.8927, Perplexity: 6.6374321:14:27
# Epoch [3/5], Step [1600/3236], Loss: 1.8927, Perplexity: 6.6374
# Epoch [3/5], Step [1700/3236], Loss: 2.0108, Perplexity: 7.4696721:20:04
# Epoch [3/5], Step [1700/3236], Loss: 2.0108, Perplexity: 7.4696
# Epoch [3/5], Step [1800/3236], Loss: 1.9080, Perplexity: 6.7395421:25:39
# Epoch [3/5], Step [1800/3236], Loss: 1.9080, Perplexity: 6.7395
# Epoch [3/5], Step [1900/3236], Loss: 1.9150, Perplexity: 6.7871521:31:16
# Epoch [3/5], Step [1900/3236], Loss: 1.9150, Perplexity: 6.7871
# Epoch [3/5], Step [2000/3236], Loss: 1.9478, Perplexity: 7.0133821:36:59
# Epoch [3/5], Step [2000/3236], Loss: 1.9478, Perplexity: 7.0133
# Epoch [3/5], Step [2100/3236], Loss: 2.0874, Perplexity: 8.0635121:42:40
# Epoch [3/5], Step [2100/3236], Loss: 2.0874, Perplexity: 8.0635
# Epoch [3/5], Step [2200/3236], Loss: 1.9269, Perplexity: 6.8679821:48:25
# Epoch [3/5], Step [2200/3236], Loss: 1.9269, Perplexity: 6.8679
# Epoch [3/5], Step [2300/3236], Loss: 2.1214, Perplexity: 8.3430421:54:10
# Epoch [3/5], Step [2300/3236], Loss: 2.1214, Perplexity: 8.3430
# Epoch [3/5], Step [2400/3236], Loss: 1.9806, Perplexity: 7.2472721:59:54
# Epoch [3/5], Step [2400/3236], Loss: 1.9806, Perplexity: 7.2472
# Epoch [3/5], Step [2500/3236], Loss: 1.8888, Perplexity: 6.6116522:05:42
# Epoch [3/5], Step [2500/3236], Loss: 1.8888, Perplexity: 6.6116
# Epoch [3/5], Step [2600/3236], Loss: 1.9811, Perplexity: 7.2505922:11:48
# Epoch [3/5], Step [2600/3236], Loss: 1.9811, Perplexity: 7.2505
# Epoch [3/5], Step [2700/3236], Loss: 2.3951, Perplexity: 10.969822:17:51
# Epoch [3/5], Step [2700/3236], Loss: 2.3951, Perplexity: 10.9698
# Epoch [3/5], Step [2800/3236], Loss: 1.9755, Perplexity: 7.2103022:24:12
# Epoch [3/5], Step [2800/3236], Loss: 1.9755, Perplexity: 7.2103
# Epoch [3/5], Step [2900/3236], Loss: 2.1765, Perplexity: 8.8157222:30:26
# Epoch [3/5], Step [2900/3236], Loss: 2.1765, Perplexity: 8.8157
# Epoch [3/5], Step [3000/3236], Loss: 1.8081, Perplexity: 6.0990522:36:48
# Epoch [3/5], Step [3000/3236], Loss: 1.8081, Perplexity: 6.0990
# Epoch [3/5], Step [3100/3236], Loss: 2.0223, Perplexity: 7.5560422:43:16
# Epoch [3/5], Step [3100/3236], Loss: 2.0223, Perplexity: 7.5560
# Epoch [3/5], Step [3200/3236], Loss: 1.9869, Perplexity: 7.2932122:48:49
# Epoch [3/5], Step [3200/3236], Loss: 1.9869, Perplexity: 7.2932
# Epoch [4/5], Step [100/3236], Loss: 2.0045, Perplexity: 7.42220822:56:22
# Epoch [4/5], Step [100/3236], Loss: 2.0045, Perplexity: 7.4222
# Epoch [4/5], Step [200/3236], Loss: 1.9771, Perplexity: 7.2220623:01:55
# Epoch [4/5], Step [200/3236], Loss: 1.9771, Perplexity: 7.2220
# Epoch [4/5], Step [300/3236], Loss: 1.9482, Perplexity: 7.0161523:07:43
# Epoch [4/5], Step [300/3236], Loss: 1.9482, Perplexity: 7.0161
# Epoch [4/5], Step [400/3236], Loss: 2.3344, Perplexity: 10.323323:13:29
# Epoch [4/5], Step [400/3236], Loss: 2.3344, Perplexity: 10.3233
# Epoch [4/5], Step [500/3236], Loss: 1.9940, Perplexity: 7.3448723:19:11
# Epoch [4/5], Step [500/3236], Loss: 1.9940, Perplexity: 7.3448
# Epoch [4/5], Step [600/3236], Loss: 1.7981, Perplexity: 6.0380623:24:50
# Epoch [4/5], Step [600/3236], Loss: 1.7981, Perplexity: 6.0380
# Epoch [4/5], Step [700/3236], Loss: 2.1775, Perplexity: 8.8239223:30:26
# Epoch [4/5], Step [700/3236], Loss: 2.1775, Perplexity: 8.8239
# Epoch [4/5], Step [800/3236], Loss: 1.9007, Perplexity: 6.6906523:36:08
# Epoch [4/5], Step [800/3236], Loss: 1.9007, Perplexity: 6.6906
# Epoch [4/5], Step [900/3236], Loss: 1.8556, Perplexity: 6.3956023:42:12
# Epoch [4/5], Step [900/3236], Loss: 1.8556, Perplexity: 6.3956
# Epoch [4/5], Step [1000/3236], Loss: 2.1366, Perplexity: 8.470823:48:16
# Epoch [4/5], Step [1000/3236], Loss: 2.1366, Perplexity: 8.4708
# Epoch [4/5], Step [1100/3236], Loss: 1.8570, Perplexity: 6.4043823:54:47
# Epoch [4/5], Step [1100/3236], Loss: 1.8570, Perplexity: 6.4043
# Epoch [4/5], Step [1200/3236], Loss: 1.9525, Perplexity: 7.0465500:01:22
# Epoch [4/5], Step [1200/3236], Loss: 1.9525, Perplexity: 7.0465
# Epoch [4/5], Step [1300/3236], Loss: 1.8138, Perplexity: 6.1339100:07:45
# Epoch [4/5], Step [1300/3236], Loss: 1.8138, Perplexity: 6.1339
# Epoch [4/5], Step [1400/3236], Loss: 1.9539, Perplexity: 7.0563700:14:38
# Epoch [4/5], Step [1400/3236], Loss: 1.9539, Perplexity: 7.0563
# Epoch [4/5], Step [1500/3236], Loss: 1.8101, Perplexity: 6.1112800:21:22
# Epoch [4/5], Step [1500/3236], Loss: 1.8101, Perplexity: 6.1112
# Epoch [4/5], Step [1600/3236], Loss: 1.9297, Perplexity: 6.8876100:28:08
# Epoch [4/5], Step [1600/3236], Loss: 1.9297, Perplexity: 6.8876
# Epoch [4/5], Step [1700/3236], Loss: 1.9582, Perplexity: 7.0866000:35:01
# Epoch [4/5], Step [1700/3236], Loss: 1.9582, Perplexity: 7.0866
# Epoch [4/5], Step [1800/3236], Loss: 1.8789, Perplexity: 6.5462100:41:35
# Epoch [4/5], Step [1800/3236], Loss: 1.8789, Perplexity: 6.5462
# Epoch [4/5], Step [1900/3236], Loss: 2.1400, Perplexity: 8.4998900:47:14
# Epoch [4/5], Step [1900/3236], Loss: 2.1400, Perplexity: 8.4998
# Epoch [4/5], Step [2000/3236], Loss: 1.9344, Perplexity: 6.9197400:53:03
# Epoch [4/5], Step [2000/3236], Loss: 1.9344, Perplexity: 6.9197
# Epoch [4/5], Step [2100/3236], Loss: 1.7923, Perplexity: 6.0030500:59:25
# Epoch [4/5], Step [2100/3236], Loss: 1.7923, Perplexity: 6.0030
# Epoch [4/5], Step [2200/3236], Loss: 1.8550, Perplexity: 6.3914901:05:37
# Epoch [4/5], Step [2200/3236], Loss: 1.8550, Perplexity: 6.3914
# Epoch [4/5], Step [2300/3236], Loss: 1.9194, Perplexity: 6.8171401:11:59
# Epoch [4/5], Step [2300/3236], Loss: 1.9194, Perplexity: 6.8171
# Epoch [4/5], Step [2400/3236], Loss: 1.9278, Perplexity: 6.8746001:18:14
# Epoch [4/5], Step [2400/3236], Loss: 1.9278, Perplexity: 6.8746
# Epoch [4/5], Step [2500/3236], Loss: 1.8032, Perplexity: 6.0693301:24:48
# Epoch [4/5], Step [2500/3236], Loss: 1.8032, Perplexity: 6.0693
# Epoch [4/5], Step [2600/3236], Loss: 2.2075, Perplexity: 9.0925601:31:13
# Epoch [4/5], Step [2600/3236], Loss: 2.2075, Perplexity: 9.0925
# Epoch [4/5], Step [2700/3236], Loss: 1.8806, Perplexity: 6.5571801:37:37
# Epoch [4/5], Step [2700/3236], Loss: 1.8806, Perplexity: 6.5571
# Epoch [4/5], Step [2800/3236], Loss: 1.9324, Perplexity: 6.9060401:43:54
# Epoch [4/5], Step [2800/3236], Loss: 1.9324, Perplexity: 6.9060
# Epoch [4/5], Step [2900/3236], Loss: 1.9136, Perplexity: 6.7775001:50:15
# Epoch [4/5], Step [2900/3236], Loss: 1.9136, Perplexity: 6.7775
# Epoch [4/5], Step [3000/3236], Loss: 2.0574, Perplexity: 7.8258201:56:35
# Epoch [4/5], Step [3000/3236], Loss: 2.0574, Perplexity: 7.8258
# Epoch [4/5], Step [3100/3236], Loss: 1.9502, Perplexity: 7.0302702:02:59
# Epoch [4/5], Step [3100/3236], Loss: 1.9502, Perplexity: 7.0302
# Epoch [4/5], Step [3200/3236], Loss: 1.9769, Perplexity: 7.2201402:09:23
# Epoch [4/5], Step [3200/3236], Loss: 1.9769, Perplexity: 7.2201
# Epoch [5/5], Step [100/3236], Loss: 1.9336, Perplexity: 6.91466802:17:23
# Epoch [5/5], Step [100/3236], Loss: 1.9336, Perplexity: 6.9146
# Epoch [5/5], Step [200/3236], Loss: 1.7997, Perplexity: 6.0480502:23:29
# Epoch [5/5], Step [200/3236], Loss: 1.7997, Perplexity: 6.0480
# Epoch [5/5], Step [300/3236], Loss: 1.9240, Perplexity: 6.8483002:29:18
# Epoch [5/5], Step [300/3236], Loss: 1.9240, Perplexity: 6.8483
# Epoch [5/5], Step [400/3236], Loss: 1.8924, Perplexity: 6.6355402:35:12
# Epoch [5/5], Step [400/3236], Loss: 1.8924, Perplexity: 6.6355
# Epoch [5/5], Step [500/3236], Loss: 1.9508, Perplexity: 7.0340602:41:08
# Epoch [5/5], Step [500/3236], Loss: 1.9508, Perplexity: 7.0340
# Epoch [5/5], Step [600/3236], Loss: 1.8344, Perplexity: 6.2614002:47:02
# Epoch [5/5], Step [600/3236], Loss: 1.8344, Perplexity: 6.2614
# Epoch [5/5], Step [700/3236], Loss: 1.9828, Perplexity: 7.2630402:52:52
# Epoch [5/5], Step [700/3236], Loss: 1.9828, Perplexity: 7.2630
# Epoch [5/5], Step [800/3236], Loss: 1.9963, Perplexity: 7.3621802:58:55
# Epoch [5/5], Step [800/3236], Loss: 1.9963, Perplexity: 7.3621
# Epoch [5/5], Step [900/3236], Loss: 2.1982, Perplexity: 9.0090003:04:49
# Epoch [5/5], Step [900/3236], Loss: 2.1982, Perplexity: 9.0090
# Epoch [5/5], Step [1000/3236], Loss: 1.8020, Perplexity: 6.061503:10:53
# Epoch [5/5], Step [1000/3236], Loss: 1.8020, Perplexity: 6.0615
# Epoch [5/5], Step [1100/3236], Loss: 1.9857, Perplexity: 7.2838803:16:54
# Epoch [5/5], Step [1100/3236], Loss: 1.9857, Perplexity: 7.2838
# Epoch [5/5], Step [1200/3236], Loss: 1.9735, Perplexity: 7.1959703:23:02
# Epoch [5/5], Step [1200/3236], Loss: 1.9735, Perplexity: 7.1959
# Epoch [5/5], Step [1300/3236], Loss: 1.8003, Perplexity: 6.0516103:29:07
# Epoch [5/5], Step [1300/3236], Loss: 1.8003, Perplexity: 6.0516
# Epoch [5/5], Step [1400/3236], Loss: 1.8880, Perplexity: 6.6058603:35:12
# Epoch [5/5], Step [1400/3236], Loss: 1.8880, Perplexity: 6.6058
# Epoch [5/5], Step [1500/3236], Loss: 1.7913, Perplexity: 5.9972303:41:09
# Epoch [5/5], Step [1500/3236], Loss: 1.7913, Perplexity: 5.9972
# Epoch [5/5], Step [1600/3236], Loss: 1.9713, Perplexity: 7.1803403:47:16
# Epoch [5/5], Step [1600/3236], Loss: 1.9713, Perplexity: 7.1803
# Epoch [5/5], Step [1700/3236], Loss: 1.9441, Perplexity: 6.9871403:53:28
# Epoch [5/5], Step [1700/3236], Loss: 1.9441, Perplexity: 6.9871
# Epoch [5/5], Step [1800/3236], Loss: 1.9423, Perplexity: 6.9748003:59:28
# Epoch [5/5], Step [1800/3236], Loss: 1.9423, Perplexity: 6.9748
# Epoch [5/5], Step [1900/3236], Loss: 1.8081, Perplexity: 6.0987404:05:33
# Epoch [5/5], Step [1900/3236], Loss: 1.8081, Perplexity: 6.0987
# Epoch [5/5], Step [2000/3236], Loss: 1.7670, Perplexity: 5.8532604:11:47
# Epoch [5/5], Step [2000/3236], Loss: 1.7670, Perplexity: 5.8532
# Epoch [5/5], Step [2100/3236], Loss: 1.7797, Perplexity: 5.9281804:17:58
# Epoch [5/5], Step [2100/3236], Loss: 1.7797, Perplexity: 5.9281
# Epoch [5/5], Step [2200/3236], Loss: 1.9788, Perplexity: 7.2342904:23:54
# Epoch [5/5], Step [2200/3236], Loss: 1.9788, Perplexity: 7.2342
# Epoch [5/5], Step [2300/3236], Loss: 2.5790, Perplexity: 13.184304:29:35
# Epoch [5/5], Step [2300/3236], Loss: 2.5790, Perplexity: 13.1843
# Epoch [5/5], Step [2400/3236], Loss: 1.7459, Perplexity: 5.7313804:35:13
# Epoch [5/5], Step [2400/3236], Loss: 1.7459, Perplexity: 5.7313
# Epoch [5/5], Step [2500/3236], Loss: 2.1034, Perplexity: 8.1938204:40:52
# Epoch [5/5], Step [2500/3236], Loss: 2.1034, Perplexity: 8.1938
# Epoch [5/5], Step [2600/3236], Loss: 1.9693, Perplexity: 7.1654104:46:30
# Epoch [5/5], Step [2600/3236], Loss: 1.9693, Perplexity: 7.1654
# Epoch [5/5], Step [2700/3236], Loss: 1.7208, Perplexity: 5.5890504:52:11
# Epoch [5/5], Step [2700/3236], Loss: 1.7208, Perplexity: 5.5890
# Epoch [5/5], Step [2800/3236], Loss: 2.0386, Perplexity: 7.6798604:57:50
# Epoch [5/5], Step [2800/3236], Loss: 2.0386, Perplexity: 7.6798
# Epoch [5/5], Step [2900/3236], Loss: 2.0645, Perplexity: 7.8812405:03:34
# Epoch [5/5], Step [2900/3236], Loss: 2.0645, Perplexity: 7.8812
# Epoch [5/5], Step [3000/3236], Loss: 1.8275, Perplexity: 6.2182705:09:20
# Epoch [5/5], Step [3000/3236], Loss: 1.8275, Perplexity: 6.2182
# Epoch [5/5], Step [3100/3236], Loss: 1.8830, Perplexity: 6.5735305:14:58
# Epoch [5/5], Step [3100/3236], Loss: 1.8830, Perplexity: 6.5735
# Epoch [5/5], Step [3200/3236], Loss: 1.9753, Perplexity: 7.2089705:20:37
# Epoch [5/5], Step [3200/3236], Loss: 1.9753, Perplexity: 7.2089
# Epoch [5/5], Step [3236/3236], Loss: 1.9235, Perplexity: 6.84520

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
